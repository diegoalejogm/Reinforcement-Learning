# %%
from IPython.display import clear_output
import gym, sys
import numpy as np

# %matplotlib inline
sys.path.append('../..')
sys.path.append('..')

import algorithms, visualize
# Out:
# (<algorithms.ActionValue instance at 0x10b22d4d0>, [-147])

# %%
# Method to run environment consecutively! 
# Make sure to run this cell
def run_environment_greedy(env, Q):
    state = env.reset()
    while(True):
        clear_output()
        print('Current State: {}'.format(state))
        action = Q.argmax(state)
        env.render()
        print('Greedy action: {}'.format(action))
        state, reward, done, _ = env.step(action)
        raw_input("Press Enter to continue...")
        if done:
            break
    clear_output()
    print('Current State: {}'.format(state))
    env.render()
    print('Finished')

# %% [markdown]
# ## Cliff Walking

# %%
env = gym.make('CliffWalking-v0')

# %%
Q, sum_rewards = algorithms.n_step_sarsa(
    num_steps=3, env=env, num_episodes=300,
    step_size=.5, discount_rate=1., epsilon=.022
)

# %%
visualize.rewards(sum_rewards)

# %% [markdown]
# ### Run Environment Interactively

# %%
run_environment_greedy(env, Q)
# Out:
# Current State: 47
# o  o  o  o  o  o  o  o  o  o  o  o
# o  o  o  o  o  o  o  o  o  o  o  o
# o  o  o  o  o  o  o  o  o  o  o  o
# o  C  C  C  C  C  C  C  C  C  C  x
#
# Finished
