# %%
import gym, sys

# %matplotlib inline
sys.path.append('../..')
sys.path.append('..')

import algorithms, visualize, utils

# %% [markdown]
# ## Cliff Walking

# %%
env = gym.make('CliffWalking-v0')

# %%
Q, sum_rewards = algorithms.n_step_backup_tree(
    num_steps=8, env=env, num_episodes=30,
    step_size=.5, discount_rate=1., epsilon=.1
)
# Out:
# Episode: 30/30

# %%
visualize.rewards(sum_rewards)

# %% [markdown]
# ### Run Environment Interactively

# %%
utils.run_environment_greedy(env, Q)
# Out:
# Current State: 47
# o  o  o  o  o  o  o  o  o  o  o  o
# o  o  o  o  o  o  o  o  o  o  o  o
# o  o  o  o  o  o  o  o  o  o  o  o
# o  C  C  C  C  C  C  C  C  C  C  x
#
# Finished
